# %%
import pandas as pd

# %%
cd /home/csheth/Documents/Work/Arunachal_Pradesh/FROG_Project/Species_delineate/Megophrys
# Out:
# /home/csheth/Documents/Work/Arunachal_Pradesh/FROG_Project/Species_delineate/Megophrys

# %%
d = pd.read_csv('/home/csheth/Documents/Work/Arunachal_Pradesh/FROG_Project/Species_delineate/Megophrys/mego_morpho.csv')

# %%
# Out:
#     IISER_Catalog_number    SVL    HL    HW  IO-A  IO-P  Eye-Snout  \
# 0                    504   47.4  15.3  18.0   8.0  14.0        6.6
# 1                    505   48.3  15.0  17.9   8.5  13.6        6.8
# 2                    506   47.4  14.3  18.5   7.8  14.0        7.1
# 3                    509   92.9  30.7  32.7  14.8  24.9       10.7
# 4                    538   68.2  23.6  26.0  11.2  21.0       10.3
# 5                    539   65.1  24.3  25.0  13.1  20.0        9.4
# 6                    544   50.7  16.0  19.6   8.3  16.0        6.8
# 7                    545   47.0  13.8  17.6   7.6  14.0        5.8
# 8                    546   65.0  18.9  22.9  10.2  17.1        7.6
# 9                    627   75.6  23.0  32.2  15.9  24.2       11.4
# 10                   630   92.4  25.2  36.3  16.3  26.2       12.6
# 11                   646   26.7   8.1  10.3   4.2   8.7        3.7
# 12                   655   74.0  27.6  28.9  17.4  23.2       11.0
# ...
